# %%
import pandas as pd 
fileName = "sample_data.csv"
df = pd.read_csv(fileName)

# %%
df.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
df.tail()
# Out:
#     show_id     type                                  title  \
# 995    s996    Movie                              Vizontele
# 996    s997    Movie                             HOMUNCULUS
# 997    s998  TV Show  Life in Color with David Attenborough
# 998    s999    Movie                   Searching For Sheela
# 999   s1000    Movie                               Stowaway
#
#                              director  \
# 995  Yılmaz Erdoğan, Ömer Faruk Sorak
# 996                   Takashi Shimizu
# 997                               NaN
# 998                               NaN
# 999                         Joe Penna
#
#                                                   cast  \
# 995  Yılmaz Erdoğan, Demet Akbağ, Altan Erkekli, Ce...
# 996  Go Ayano, Ryo Narita, Yukino Kishii, Anna Ishi...
# 997                                 David Attenborough
# 998                                    Ma Anand Sheela
# 999  Anna Kendrick, Toni Collette, Daniel Dae Kim, ...
#
# ...

# %%
df.shape
# Out:
# (1000, 12)

# %%
df.size
# Out:
# 12000

# %%
df.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %%
df.dtypes
# Out:
# show_id         object
# type            object
# title           object
# director        object
# cast            object
# country         object
# date_added      object
# release_year     int64
# rating          object
# duration        object
# listed_in       object
# description     object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       1000 non-null   object
#  1   type          1000 non-null   object
#  2   title         1000 non-null   object
#  3   director      685 non-null    object
#  4   cast          903 non-null    object
#  5   country       694 non-null    object
#  6   date_added    1000 non-null   object
#  7   release_year  1000 non-null   int64
#  8   rating        1000 non-null   object
#  9   duration      1000 non-null   object
#  10  listed_in     1000 non-null   object
#  11  description   1000 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 93.9+ KB

# %%
df.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
df.shape
# Out:
# (1000, 12)

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [show_id, type, title, director, cast, country, date_added, release_year, rating, duration, listed_in, description]
# Index: []

# %%
df.drop_duplicates(inplace=True)

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [show_id, type, title, director, cast, country, date_added, release_year, rating, duration, listed_in, description]
# Index: []

# %%
df.isnull().sum()
# Out:
# show_id           0
# type              0
# title             0
# director        315
# cast             97
# country         306
# date_added        0
# release_year      0
# rating            0
# duration          0
# listed_in         0
# description       0
# dtype: int64

# %%
import seaborn as sns

# %%
df.isnull()
# Out:
#      show_id   type  title  director   cast  country  date_added  \
# 0      False  False  False     False   True    False       False
# 1      False  False  False      True  False    False       False
# 2      False  False  False     False  False     True       False
# 3      False  False  False      True   True     True       False
# 4      False  False  False      True  False    False       False
# ..       ...    ...    ...       ...    ...      ...         ...
# 995    False  False  False     False  False    False       False
# 996    False  False  False     False  False    False       False
# 997    False  False  False      True  False    False       False
# 998    False  False  False      True  False    False       False
# 999    False  False  False     False  False    False       False
#
#      release_year  rating  duration  listed_in  description
# 0           False   False     False      False        False
# 1           False   False     False      False        False
# ...

# %%
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %%
df.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
df[df['title'].isin(['Blood & Water'])]
# Out:
#   show_id     type          title director  \
# 1      s2  TV Show  Blood & Water      NaN
#
#                                                 cast       country  \
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...  South Africa
#
#            date_added  release_year rating   duration  \
# 1  September 24, 2021          2021  TV-MA  2 Seasons
#
#                                          listed_in  \
# 1  International TV Shows, TV Dramas, TV Mysteries
#
#                                          description
# 1  After crossing paths at a party, a Cape Town t...

# %%
df[df['title'].str.contains('House of Cards')]
# Out:
# Empty DataFrame
# Columns: [show_id, type, title, director, cast, country, date_added, release_year, rating, duration, listed_in, description]
# Index: []

# %%
df.dtypes
# Out:
# show_id         object
# type            object
# title           object
# director        object
# cast            object
# country         object
# date_added      object
# release_year     int64
# rating          object
# duration        object
# listed_in       object
# description     object
# dtype: object

# %%
df['data_date'] = pd.to_datetime(df['release_year'])

# %%
df.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
from dateutil import parser

# Replace 'your_date_string' with the actual date string causing the error
date_string = " August 4, 2017"
parsed_date = parser.parse(date_string, dayfirst=True)

# %%
bar = df['data_date'].dt.year.value_counts()

# %%
df.isna().any()
# Out:
# show_id         False
# type            False
# title           False
# director         True
# cast             True
# country          True
# date_added      False
# release_year    False
# rating          False
# duration        False
# listed_in       False
# description     False
# data_date       False
# dtype: bool

# %%
bar.plot(kind='bar')
# Out:
# <Axes: xlabel='data_date'>

# %%
df.head(2)
# Out:
#   show_id     type                 title         director  \
# 0      s1    Movie  Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show         Blood & Water              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
#
#                                          listed_in  \
# 0                                    Documentaries
# 1  International TV Shows, TV Dramas, TV Mysteries
#
#                                          description  \
# 0  As her father nears the end of his life, filmm...
# 1  After crossing paths at a party, a Cape Town t...
#
#                       data_date
# 0 1970-01-01 00:00:00.000002020
# ...

# %%
movie = df.groupby('type').type.count()

# %%
movie
# Out:
# type
# Movie      655
# TV Show    345
# Name: type, dtype: int64

# %%
sns.countplot(df['type'])
# Out:
# <Axes: xlabel='count', ylabel='type'>

# %%
df.head(2)
# Out:
#   show_id     type                 title         director  \
# 0      s1    Movie  Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show         Blood & Water              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
#
#                                          listed_in  \
# 0                                    Documentaries
# 1  International TV Shows, TV Dramas, TV Mysteries
#
#                                          description  \
# 0  As her father nears the end of his life, filmm...
# 1  After crossing paths at a party, a Cape Town t...
#
#                       data_date
# 0 1970-01-01 00:00:00.000002020
# ...

# %%
df[(df['type']== 'title') & (df['data_date']== 2010)]
# Out:
# Empty DataFrame
# Columns: [show_id, type, title, director, cast, country, date_added, release_year, rating, duration, listed_in, description, data_date]
# Index: []

# %%
df.head(2)
# Out:
#   show_id     type                 title         director  \
# 0      s1    Movie  Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show         Blood & Water              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
#
#                                          listed_in  \
# 0                                    Documentaries
# 1  International TV Shows, TV Dramas, TV Mysteries
#
#                                          description  \
# 0  As her father nears the end of his life, filmm...
# 1  After crossing paths at a party, a Cape Town t...
#
#                       data_date
# 0 1970-01-01 00:00:00.000002020
# ...

# %%
df[(df['type']=='TV Show') & (df['country'] == 'India')]  ['title']
# Out:
# 4                        Kota Factory
# 39                       Chhota Bheem
# 50                      Dharmakshetra
# 66      Raja Rasoi Aur Anya Kahaniyan
# 69     Stories by Rabindranath Tagore
# 266              The Creative Indians
# 297                          Navarasa
# 876                      Alma Matters
# 911                  Sab Jholmaal Hai
# 918                    Lava Ka Dhaava
# Name: title, dtype: object

# %%
df.head(3)
# Out:
#   show_id     type                 title         director  \
# 0      s1    Movie  Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show         Blood & Water              NaN
# 2      s3  TV Show             Ganglands  Julien Leclercq
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# 2  September 24, 2021          2021  TV-MA   1 Season
#
#                                            listed_in  \
# 0                                      Documentaries
# 1    International TV Shows, TV Dramas, TV Mysteries
# 2  Crime TV Shows, International TV Shows, TV Act...
#
# ...

# %%
df['director'].value_counts().head(10)
# Out:
# director
# Rajiv Chilaka          16
# Suhas Kadav             5
# Clint Eastwood          4
# Milan Luthria           4
# Rathindran R Prasad     4
# Toshiya Shinohara       4
# Soudade Kaadan          3
# Jane Campion            3
# Leigh Janiak            3
# Lasse Hallström         3
# Name: count, dtype: int64

# %%
df[(df['type']=='Movie')&(df['listed_in']=='Comedies') | (df['country']=='United States')]
# Out:
#     show_id     type                             title            director  \
# 0        s1    Movie              Dick Johnson Is Dead     Kirsten Johnson
# 9       s10    Movie                      The Starling      Theodore Melfi
# 15      s16  TV Show                 Dear White People                 NaN
# 27      s28    Movie                         Grown Ups        Dennis Dugan
# 28      s29    Movie                        Dark Skies       Scott Stewart
# ..      ...      ...                               ...                 ...
# 956    s957    Movie        Zack and Miri Make a Porno         Kevin Smith
# 969    s970    Movie              August: Osage County          John Wells
# 970    s971    Movie               Battle: Los Angeles  Jonathan Liebesman
# 975    s976    Movie  Shadow and Bone - The Afterparty                 NaN
# 993    s994  TV Show                   Shadow and Bone                 NaN
#
# ...

# %%
df[(df['type']=='title')&(df['cast']=='Tom Cruise')]
# Out:
# Empty DataFrame
# Columns: [show_id, type, title, director, cast, country, date_added, release_year, rating, duration, listed_in, description, data_date]
# Index: []

# %%
df['cast']=='Tom Cruise'
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 995    False
# 996    False
# 997    False
# 998    False
# 999    False
# Name: cast, Length: 1000, dtype: bool

# %%
df['cast'].str.contains('Tom Cruise')
# Out:
# 0        NaN
# 1      False
# 2      False
# 3        NaN
# 4      False
#        ...
# 995    False
# 996    False
# 997    False
# 998    False
# 999    False
# Name: cast, Length: 1000, dtype: object

# %%
new_df = df.dropna()

# %%
new_df.isna().any()
# Out:
# show_id         False
# type            False
# title           False
# director        False
# cast            False
# country         False
# date_added      False
# release_year    False
# rating          False
# duration        False
# listed_in       False
# description     False
# data_date       False
# dtype: bool

# %%
new_df.nunique()
# Out:
# show_id         463
# type              2
# title           463
# director        417
# cast            463
# country         111
# date_added      107
# release_year     48
# rating            9
# duration         90
# listed_in       130
# description     463
# data_date        48
# dtype: int64

# %%
new_df[new_df['cast'].str.contains('Tom Cruise')]
# Out:
#     show_id   type     title              director  \
# 341    s342  Movie  Magnolia  Paul Thomas Anderson
#
#                                                   cast        country  \
# 341  John C. Reilly, Philip Baker Hall, Tom Cruise,...  United States
#
#          date_added  release_year rating duration                   listed_in  \
# 341  August 1, 2021          1999      R  189 min  Dramas, Independent Movies
#
#                                            description  \
# 341  Through chance, history and divine interventio...
#
#                         data_date
# 341 1970-01-01 00:00:00.000001999

# %%
new_df['rating'].unique()
# Out:
# array(['TV-MA', 'TV-14', 'PG-13', 'PG', 'R', 'TV-PG', 'G', 'TV-Y7',
#        'TV-G'], dtype=object)

# %%
new_df[(new_df['type']=='Movie')&(new_df['country']=='Canada')]
# Out:
#     show_id   type                title                             director  \
# 157    s158  Movie             Level 16                   Danishka Esterhazy
# 701    s702  Movie             Red Snow                       Marie Clements
# 954    s955  Movie  The Yeti Adventures  Pierre Greco, Nancy Florence Savard
#
#                                                   cast country  \
# 157  Katie Douglas, Celina Martin, Peter Outerbridg...  Canada
# 701  Asivak Koostachin, Shafin Karim, Mozhdah Jamal...  Canada
# 954  Rachelle Lefevre, Noel Fisher, Colm Feore, Jul...  Canada
#
#             date_added  release_year rating duration  \
# 157  September 1, 2021          2018  TV-14  102 min
# 701      June 17, 2021          2019  TV-MA   96 min
# 954        May 1, 2021          2018  TV-PG   85 min
#
#                               listed_in  \
# 157         Sci-Fi & Fantasy, Thrillers
# 701                              Dramas
# 954  Children & Family Movies, Comedies
#
# ...

# %%
new_df[(new_df['type']=='Movie')&(new_df['country']=='United States')&(new_df['rating']=='TV-14')]
# Out:
#     show_id   type                       title             director  \
# 800    s801  Movie             Mosquita y Mari      Aurora Guerrero
# 870    s871  Movie  Amy Tan: Unintended Memoir        James Redford
# 948    s949  Movie                      Swiped  Ann Deborah Fishman
#
#                                                   cast        country  \
# 800  Fenessa Pineda, Venecia Troncoso, Joaquín Garr...  United States
# 870                                            Amy Tan  United States
# 948  Kendall Ryan Sanders, Noah Centineo, Nathan Ga...  United States
#
#        date_added  release_year rating duration  \
# 800  June 2, 2021          2012  TV-14   85 min
# 870  May 18, 2021          2021  TV-14  101 min
# 948   May 1, 2021          2018  TV-14   94 min
#
#                                     listed_in  \
# 800  Dramas, Independent Movies, LGBTQ Movies
# 870                             Documentaries
# 948                                  Comedies
#
# ...

# %%
new_df[(new_df['type'] == 'Movie')&(new_df['listed_in']=='Daramas')]
# Out:
# Empty DataFrame
# Columns: [show_id, type, title, director, cast, country, date_added, release_year, rating, duration, listed_in, description, data_date]
# Index: []

# %%
new_df[(new_df['rating']=='R')&(new_df['type']=='Movie')]
# Out:
#     show_id   type                         title               director  \
# 46      s47  Movie                    Safe House        Daniel Espinosa
# 48      s49  Movie                  Training Day          Antoine Fuqua
# 81      s82  Movie                          Kate  Cedric Nicolas-Troyan
# 122    s123  Movie                    In the Cut           Jane Campion
# 131    s132  Movie   Blade Runner: The Final Cut           Ridley Scott
# ..      ...    ...                           ...                    ...
# 955    s956  Movie                   Under Siege           Andrew Davis
# 956    s957  Movie    Zack and Miri Make a Porno            Kevin Smith
# 962    s963  Movie  The Strangers: Prey at Night       Johannes Roberts
# 969    s970  Movie          August: Osage County             John Wells
# 971    s972  Movie                Between Worlds           Maria Pulera
#
#                                                   cast  \
# ...

# %%
new_df[(new_df['rating']=='R')&(new_df['type']=='TV Show')&(new_df['release_year']>1970)]
# Out:
# Empty DataFrame
# Columns: [show_id, type, title, director, cast, country, date_added, release_year, rating, duration, listed_in, description, data_date]
# Index: []

# %%
df.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
new_df.head(2)
# Out:
#   show_id     type                          title         director  \
# 7      s8    Movie                        Sankofa     Haile Gerima
# 8      s9  TV Show  The Great British Baking Show  Andy Devonshire
#
#                                                 cast  \
# 7  Kofi Ghanaba, Oyafunmike Ogunlano, Alexandra D...
# 8  Mel Giedroyc, Sue Perkins, Mary Berry, Paul Ho...
#
#                                              country          date_added  \
# 7  United States, Ghana, Burkina Faso, United Kin...  September 24, 2021
# 8                                     United Kingdom  September 24, 2021
#
#    release_year rating   duration  \
# 7          1993  TV-MA    125 min
# 8          2021  TV-14  9 Seasons
#
#                                           listed_in  \
# 7  Dramas, Independent Movies, International Movies
# 8                      British TV Shows, Reality TV
#
#                                          description  \
# ...

# %%
new_df.duration.unique()
# Out:
# array(['125 min', '9 Seasons', '104 min', '127 min', '166 min', '103 min',
#        '97 min', '106 min', '96 min', '124 min', '116 min', '98 min',
#        '91 min', '115 min', '122 min', '99 min', '88 min', '100 min',
#        '102 min', '93 min', '95 min', '85 min', '83 min', '182 min',
#        '147 min', '90 min', '128 min', '143 min', '119 min', '114 min',
#        '118 min', '108 min', '117 min', '121 min', '142 min', '113 min',
#        '154 min', '120 min', '82 min', '94 min', '109 min', '101 min',
#        '105 min', '86 min', '229 min', '76 min', '89 min', '110 min',
#        '156 min', '112 min', '129 min', '107 min', '1 Season', '135 min',
#        '136 min', '165 min', '150 min', '133 min', '145 min', '92 min',
#        '2 Seasons', '64 min', '59 min', '111 min', '87 min', '148 min',
#        '189 min', '141 min', '130 min', '7 Seasons', '68 min', '131 min',
#        '126 min', '155 min', '123 min', '84 min', '4 Seasons', '13 min',
# ...

# %%
new_df.head(2)
# Out:
#   show_id     type                          title         director  \
# 7      s8    Movie                        Sankofa     Haile Gerima
# 8      s9  TV Show  The Great British Baking Show  Andy Devonshire
#
#                                                 cast  \
# 7  Kofi Ghanaba, Oyafunmike Ogunlano, Alexandra D...
# 8  Mel Giedroyc, Sue Perkins, Mary Berry, Paul Ho...
#
#                                              country          date_added  \
# 7  United States, Ghana, Burkina Faso, United Kin...  September 24, 2021
# 8                                     United Kingdom  September 24, 2021
#
#    release_year rating   duration  \
# 7          1993  TV-MA    125 min
# 8          2021  TV-14  9 Seasons
#
#                                           listed_in  \
# 7  Dramas, Independent Movies, International Movies
# 8                      British TV Shows, Reality TV
#
#                                          description  \
# ...

# %%
new_df.duration.unique()
# Out:
# array(['125 min', '9 Seasons', '104 min', '127 min', '166 min', '103 min',
#        '97 min', '106 min', '96 min', '124 min', '116 min', '98 min',
#        '91 min', '115 min', '122 min', '99 min', '88 min', '100 min',
#        '102 min', '93 min', '95 min', '85 min', '83 min', '182 min',
#        '147 min', '90 min', '128 min', '143 min', '119 min', '114 min',
#        '118 min', '108 min', '117 min', '121 min', '142 min', '113 min',
#        '154 min', '120 min', '82 min', '94 min', '109 min', '101 min',
#        '105 min', '86 min', '229 min', '76 min', '89 min', '110 min',
#        '156 min', '112 min', '129 min', '107 min', '1 Season', '135 min',
#        '136 min', '165 min', '150 min', '133 min', '145 min', '92 min',
#        '2 Seasons', '64 min', '59 min', '111 min', '87 min', '148 min',
#        '189 min', '141 min', '130 min', '7 Seasons', '68 min', '131 min',
#        '126 min', '155 min', '123 min', '84 min', '4 Seasons', '13 min',
# ...

# %%
new_df.duration.dtypes
# Out:
# dtype('O')

# %%
new_df[['Min','unit']] = new_df['duration'].str.split(' ',expand=True)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_8852\1396480838.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df[['Min','unit']] = new_df['duration'].str.split(' ',expand=True)

# %%
new_df.head()
# Out:
#    show_id     type                          title             director  \
# 7       s8    Movie                        Sankofa         Haile Gerima
# 8       s9  TV Show  The Great British Baking Show      Andy Devonshire
# 9      s10    Movie                   The Starling       Theodore Melfi
# 12     s13    Movie                   Je Suis Karl  Christian Schwochow
# 24     s25    Movie                          Jeans           S. Shankar
#
#                                                  cast  \
# 7   Kofi Ghanaba, Oyafunmike Ogunlano, Alexandra D...
# 8   Mel Giedroyc, Sue Perkins, Mary Berry, Paul Ho...
# 9   Melissa McCarthy, Chris O'Dowd, Kevin Kline, T...
# 12  Luna Wedler, Jannis Niewöhner, Milan Peschel, ...
# 24  Prashanth, Aishwarya Rai Bachchan, Sri Lakshmi...
#
#                                               country          date_added  \
# 7   United States, Ghana, Burkina Faso, United Kin...  September 24, 2021
# ...

# %%
new_df.Min.max()
# Out:
# '99'

# %%
new_df.Min.min()
# Out:
# '1'

# %%
tv_show = new_df['type'] == 'TV Show'

# %%
tv_show.head()
# Out:
# 7     False
# 8      True
# 9     False
# 12    False
# 24    False
# Name: type, dtype: bool

# %%
new_df.country.value_counts()
# Out:
# country
# United States                                 183
# India                                          48
# Nigeria                                        17
# Japan                                          14
# Turkey                                         14
#                                              ...
# Taiwan                                          1
# United States, Nigeria                          1
# Argentina, Spain                                1
# Switzerland, United Kingdom, Australia          1
# United States, United Kingdom, New Zealand      1
# Name: count, Length: 111, dtype: int64

# %%
new_df.country.value_counts().max()
# Out:
# 183

# %%
new_df.country.value_counts().head(1)
# Out:
# country
# United States    183
# Name: count, dtype: int64

# %%
sorting = new_df.sort_values(by='release_year').head()

# %%
sorting.sort_values(by='release_year',ascending=False)
# Out:
#     show_id   type                       title          director  \
# 529    s530  Movie  Return of the Prodigal Son   Youssef Chahine
# 41      s42  Movie                        Jaws  Steven Spielberg
# 716    s717  Movie                         FTA   Francine Parker
# 177    s178  Movie        The Guns of Navarone   J. Lee Thompson
# 542    s543  Movie                       Ujala     Naresh Saigal
#
#                                                   cast  \
# 529  Majida El Roumi, Souheir El Morshidy, Shoukry ...
# 41   Roy Scheider, Robert Shaw, Richard Dreyfuss, L...
# 716  Jane Fonda, Donald Sutherland, Pamela Donegan,...
# 177  Gregory Peck, David Niven, Anthony Quinn, Stan...
# 542  Mala Sinha, Shammi Kapoor, Raaj Kumar, Leela C...
#
#                            country          date_added  release_year rating  \
# 529                          Egypt        July 6, 2021          1976  TV-MA
# 41                   United States  September 16, 2021          1975     PG
# ...

# %%
sorting.sort_values(by='release_year',ascending=True)
# Out:
#     show_id   type                       title          director  \
# 542    s543  Movie                       Ujala     Naresh Saigal
# 177    s178  Movie        The Guns of Navarone   J. Lee Thompson
# 716    s717  Movie                         FTA   Francine Parker
# 41      s42  Movie                        Jaws  Steven Spielberg
# 529    s530  Movie  Return of the Prodigal Son   Youssef Chahine
#
#                                                   cast  \
# 542  Mala Sinha, Shammi Kapoor, Raaj Kumar, Leela C...
# 177  Gregory Peck, David Niven, Anthony Quinn, Stan...
# 716  Jane Fonda, Donald Sutherland, Pamela Donegan,...
# 41   Roy Scheider, Robert Shaw, Richard Dreyfuss, L...
# 529  Majida El Roumi, Souheir El Morshidy, Shoukry ...
#
#                            country          date_added  release_year rating  \
# 542                          India        July 6, 2021          1959  TV-14
# 177  United Kingdom, United States   September 1, 2021          1961  TV-14
# ...

# %%
new_df[(new_df['type']=='Movie')&(new_df['listed_in']=='Dramas') ]
# Out:
#     show_id   type                title             director  \
# 129    s130  Movie   An Unfinished Life      Lasse Hallström
# 142    s143  Movie      Freedom Writers  Richard LaGravenese
# 162    s163  Movie             Marshall      Reginald Hudlin
# 329    s330  Movie  Catch Me If You Can     Steven Spielberg
# 343    s344  Movie              My Girl         Howard Zieff
#
#                                                   cast  \
# 129  Robert Redford, Jennifer Lopez, Morgan Freeman...
# 142  Hilary Swank, Patrick Dempsey, Scott Glenn, Im...
# 162  Chadwick Boseman, Josh Gad, Kate Hudson, Sterl...
# 329  Leonardo DiCaprio, Tom Hanks, Christopher Walk...
# 343  Dan Aykroyd, Jamie Lee Curtis, Macaulay Culkin...
#
#                              country         date_added  release_year rating  \
# 129           Germany, United States  September 1, 2021          2005  PG-13
# 142           Germany, United States  September 1, 2021          2007  PG-13
# ...

# %%
new_df[(new_df['type']=='TV Shows')&(new_df['listed_in']=="Kids' Tv")]
# Out:
# Empty DataFrame
# Columns: [show_id, type, title, director, cast, country, date_added, release_year, rating, duration, listed_in, description, data_date, Min, unit]
# Index: []

# %%
new_df[(new_df['type']=='Movie')&(new_df['listed_in']=='Dramas') | (new_df['type']=='TV Shpws')&(new_df['listed_in']=="Kids' TV") ]
# Out:
#     show_id   type                   title  \
# 129    s130  Movie      An Unfinished Life
# 142    s143  Movie         Freedom Writers
# 162    s163  Movie                Marshall
# 329    s330  Movie     Catch Me If You Can
# 343    s344  Movie                 My Girl
# 426    s427  Movie                 Cousins
# 446    s447  Movie       The Book of Henry
# 599    s600  Movie     The Best of Enemies
# 604    s605  Movie  The Life of David Gale
# 630    s631  Movie     Killing Them Softly
# 685    s686  Movie              Fatherhood
# 701    s702  Movie                Red Snow
# 797    s798  Movie                I Am Sam
# 828    s829  Movie       Collateral Beauty
# 910    s911  Movie                 Monster
# 969    s970  Movie    August: Osage County
#
#                                 director  \
# 129                      Lasse Hallström
# 142                  Richard LaGravenese
# 162                      Reginald Hudlin
# 329                     Steven Spielberg
# ...
